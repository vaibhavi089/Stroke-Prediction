# %% [markdown]
# **Importing Libraries**

# %%
# !pip install catboost
# !pip install optuna
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier,StackingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier, Pool
from imblearn.combine import SMOTEENN
import optuna
import shap
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 6.0 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 15.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0

# %% [markdown]
# LOADING AND PREPROCESSING DATA

# %%
df = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')

# %%
df['bmi'] = df['bmi'].fillna(df['bmi'].median())
df.drop('id',axis=1,inplace=True)

# %% [markdown]
# FEATURE ENGINEERING

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21  28.1     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df['age_glucose'] = df['age'] * df['avg_glucose_level']
df['bmi_age_ratio'] = df['bmi'] / (df['age'] + 1)
df = pd.get_dummies(df, drop_first=True)

# %%
X = df.drop('stroke', axis=1)
y = df['stroke']

# %% [markdown]
# RESAMPLE

# %%
smote_enn = SMOTEENN(random_state=42)
X_res, y_res = smote_enn.fit_resample(X, y)

# %% [markdown]
# TRAIN/TEST SPLIT

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)

# %% [markdown]
# SCALE FEATURES

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Feature Selection with SHAP on LightGBM

# %%
lgbm = LGBMClassifier(random_state=42)
lgbm.fit(X_train_scaled, y_train)
explainer = shap.TreeExplainer(lgbm)
shap_values = explainer.shap_values(X_train_scaled)
shap_abs_mean = np.abs(shap_values).mean(axis=0)
important_features_idx = np.argsort(shap_abs_mean)[-15:]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 2906, number of negative: 2490
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001081 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1308
# [LightGBM] [Info] Number of data points in the train set: 5396, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.538547 -> initscore=0.154495
# [LightGBM] [Info] Start training from score 0.154495
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_tree.py:583: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(

# %%
X_train_sel = X_train_scaled[:, important_features_idx]
X_test_sel = X_test_scaled[:, important_features_idx]

# %% [markdown]
# HYPERPARAMETER OPTIMIZATION WITH OPTUNA

# %%
def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'random_state': 42,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }
    xgb = XGBClassifier(**param)
    xgb.fit(X_train_sel, y_train)
    preds = xgb.predict(X_test_sel)
    return accuracy_score(y_test, preds)

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)
best_params = study.best_params
# Out:
# [I 2025-06-06 14:33:41,202] A new study created in memory with name: no-name-02201028-6b24-4520-b3b2-e9e393400270
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:41,718] Trial 0 finished with value: 0.9822090437361009 and parameters: {'n_estimators': 248, 'max_depth': 8, 'learning_rate': 0.07055491367559284, 'subsample': 0.8979187570837075, 'colsample_bytree': 0.8974771351506733}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:42,242] Trial 1 finished with value: 0.9644180874722016 and parameters: {'n_estimators': 203, 'max_depth': 8, 'learning_rate': 0.012022570500134007, 'subsample': 0.9896581614973698, 'colsample_bytree': 0.9640203861472302}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:42,356] Trial 2 finished with value: 0.9629355077835434 and parameters: {'n_estimators': 159, 'max_depth': 3, 'learning_rate': 0.0948903193102753, 'subsample': 0.6687194346482377, 'colsample_bytree': 0.5047573958012643}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:42,577] Trial 3 finished with value: 0.9681245366938473 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.04792439052359263, 'subsample': 0.5652085194935365, 'colsample_bytree': 0.5574554671418426}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:42,859] Trial 4 finished with value: 0.9799851742031134 and parameters: {'n_estimators': 176, 'max_depth': 10, 'learning_rate': 0.2789165661524902, 'subsample': 0.562078961870327, 'colsample_bytree': 0.949287007810498}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:43,040] Trial 5 finished with value: 0.9762787249814677 and parameters: {'n_estimators': 122, 'max_depth': 6, 'learning_rate': 0.19749774885012483, 'subsample': 0.5091171998372053, 'colsample_bytree': 0.9283263209751025}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:43,180] Trial 6 finished with value: 0.9785025945144552 and parameters: {'n_estimators': 85, 'max_depth': 6, 'learning_rate': 0.21887435252813, 'subsample': 0.9256489226454017, 'colsample_bytree': 0.8733369770592555}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:43,373] Trial 7 finished with value: 0.9785025945144552 and parameters: {'n_estimators': 153, 'max_depth': 6, 'learning_rate': 0.16497539631346964, 'subsample': 0.7631362159584041, 'colsample_bytree': 0.5856357064893072}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:43,451] Trial 8 finished with value: 0.9666419570051891 and parameters: {'n_estimators': 87, 'max_depth': 3, 'learning_rate': 0.22255868453640426, 'subsample': 0.7250384634021529, 'colsample_bytree': 0.5457837576980507}. Best is trial 0 with value: 0.9822090437361009.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:43,744] Trial 9 finished with value: 0.9829503335804299 and parameters: {'n_estimators': 292, 'max_depth': 4, 'learning_rate': 0.17491630214244766, 'subsample': 0.6043289329559837, 'colsample_bytree': 0.8539971185668569}. Best is trial 9 with value: 0.9829503335804299.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:44,039] Trial 10 finished with value: 0.9785025945144552 and parameters: {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.12718961113561952, 'subsample': 0.6565198952494209, 'colsample_bytree': 0.7714026707856284}. Best is trial 9 with value: 0.9829503335804299.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:44,531] Trial 11 finished with value: 0.9836916234247591 and parameters: {'n_estimators': 294, 'max_depth': 8, 'learning_rate': 0.08874585259403703, 'subsample': 0.8473781106245515, 'colsample_bytree': 0.8143761803048979}. Best is trial 11 with value: 0.9836916234247591.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:44,986] Trial 12 finished with value: 0.9829503335804299 and parameters: {'n_estimators': 290, 'max_depth': 8, 'learning_rate': 0.1361692592379711, 'subsample': 0.8126690997208335, 'colsample_bytree': 0.7813012088296682}. Best is trial 11 with value: 0.9836916234247591.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:45,372] Trial 13 finished with value: 0.9814677538917717 and parameters: {'n_estimators': 252, 'max_depth': 10, 'learning_rate': 0.1678013051483162, 'subsample': 0.8386201273157217, 'colsample_bytree': 0.6810525249484904}. Best is trial 11 with value: 0.9836916234247591.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:45,982] Trial 14 finished with value: 0.9814677538917717 and parameters: {'n_estimators': 272, 'max_depth': 7, 'learning_rate': 0.10647302432877044, 'subsample': 0.6514500837290544, 'colsample_bytree': 0.8361608729867333}. Best is trial 11 with value: 0.9836916234247591.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:48,031] Trial 15 finished with value: 0.9851742031134173 and parameters: {'n_estimators': 210, 'max_depth': 5, 'learning_rate': 0.29787282209539323, 'subsample': 0.7377503840727486, 'colsample_bytree': 0.6979333054983232}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:48,282] Trial 16 finished with value: 0.9814677538917717 and parameters: {'n_estimators': 212, 'max_depth': 5, 'learning_rate': 0.2916979787407102, 'subsample': 0.7496268074185579, 'colsample_bytree': 0.6819794970784119}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:48,577] Trial 17 finished with value: 0.9799851742031134 and parameters: {'n_estimators': 206, 'max_depth': 9, 'learning_rate': 0.25102434820056974, 'subsample': 0.8452868224680588, 'colsample_bytree': 0.6801573351243239}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:48,723] Trial 18 finished with value: 0.9584877687175686 and parameters: {'n_estimators': 52, 'max_depth': 7, 'learning_rate': 0.025816588109195585, 'subsample': 0.9044778730662607, 'colsample_bytree': 0.7337103793820107}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:49,037] Trial 19 finished with value: 0.977761304670126 and parameters: {'n_estimators': 224, 'max_depth': 5, 'learning_rate': 0.07478077332115195, 'subsample': 0.7915575694196475, 'colsample_bytree': 0.6449611025588529}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:49,266] Trial 20 finished with value: 0.9814677538917717 and parameters: {'n_estimators': 179, 'max_depth': 5, 'learning_rate': 0.2543814426304594, 'subsample': 0.7055584747132781, 'colsample_bytree': 0.8086259647189287}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:49,537] Trial 21 finished with value: 0.9807264640474426 and parameters: {'n_estimators': 272, 'max_depth': 4, 'learning_rate': 0.18715032927127834, 'subsample': 0.6132337728520988, 'colsample_bytree': 0.8545603151155551}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:49,851] Trial 22 finished with value: 0.9814677538917717 and parameters: {'n_estimators': 278, 'max_depth': 5, 'learning_rate': 0.13763424211150307, 'subsample': 0.8757817999202104, 'colsample_bytree': 0.7381998791697549}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:50,124] Trial 23 finished with value: 0.9807264640474426 and parameters: {'n_estimators': 230, 'max_depth': 4, 'learning_rate': 0.11181970483425477, 'subsample': 0.9816086232350916, 'colsample_bytree': 0.8102686719224128}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:50,468] Trial 24 finished with value: 0.9807264640474426 and parameters: {'n_estimators': 262, 'max_depth': 9, 'learning_rate': 0.25544282304365795, 'subsample': 0.7014727719980078, 'colsample_bytree': 0.9984142514334696}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:50,918] Trial 25 finished with value: 0.9807264640474426 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.07321607321162353, 'subsample': 0.597089502300415, 'colsample_bytree': 0.8918998264295881}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:51,145] Trial 26 finished with value: 0.9770200148257969 and parameters: {'n_estimators': 239, 'max_depth': 3, 'learning_rate': 0.29910614361734134, 'subsample': 0.5033450762029094, 'colsample_bytree': 0.6145044410283909}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:51,685] Trial 27 finished with value: 0.9822090437361009 and parameters: {'n_estimators': 284, 'max_depth': 9, 'learning_rate': 0.044938861794883114, 'subsample': 0.7911041202249515, 'colsample_bytree': 0.7111772191171877}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:51,879] Trial 28 finished with value: 0.9836916234247591 and parameters: {'n_estimators': 128, 'max_depth': 6, 'learning_rate': 0.22656745380957688, 'subsample': 0.9587043090536532, 'colsample_bytree': 0.8150399052436731}. Best is trial 15 with value: 0.9851742031134173.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:33:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:33:52,076] Trial 29 finished with value: 0.9799851742031134 and parameters: {'n_estimators': 115, 'max_depth': 6, 'learning_rate': 0.22279832771598582, 'subsample': 0.9313262166415343, 'colsample_bytree': 0.7834899402141648}. Best is trial 15 with value: 0.9851742031134173.

# %% [markdown]
# OPTIMIZED BASE MODEL WITH BEST PARAMS

# %%
xgb_opt = XGBClassifier(**best_params)
lgbm_opt = LGBMClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    learning_rate=best_params['learning_rate'],
    subsample=best_params['subsample'],
    colsample_bytree=best_params['colsample_bytree'],
    random_state=42
)
catboost_opt = CatBoostClassifier(verbose=0, random_seed=42)
svc_opt = SVC(probability=True, random_state=42)

estimators = [
    ('xgb', xgb_opt),
    ('lgbm', lgbm_opt),
    ('catboost', catboost_opt),
    ('svc', svc_opt)
]

# %% [markdown]
# STACKING CLASSIFIER WITH LOGISTIC REG

# %%
stacking_clf = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression(max_iter=1000),
    cv=StratifiedKFold(n_splits=5),
    n_jobs=-1,
    passthrough=False
)

# %% [markdown]
# COMBINING STACKING WITH VOTING CLASSIFIER

# %%
#used soft voting here
voting_clf = VotingClassifier(
    estimators=[
        ('stacking', stacking_clf),
        ('lgbm', lgbm_opt),
        ('catboost', catboost_opt)
    ],
    voting='soft',
    n_jobs=-1
)

# %% [markdown]
# TRAINING

# %%
voting_clf.fit(X_train_sel, y_train)
# Out:
# VotingClassifier(estimators=[('stacking',
#                               StackingClassifier(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                                                  estimators=[('xgb',
#                                                               XGBClassifier(base_score=None,
#                                                                             booster=None,
#                                                                             callbacks=None,
#                                                                             colsample_bylevel=None,
#                                                                             colsample_bynode=None,
#                                                                             colsample_bytree=0.6979333054983232,
#                                                                             device=None,
#                                                                             early_stopping_rounds=None,
#                                                                             enable_categorical=False,
#                                                                             eval_...
#                                                               SVC(probability=True,
#                                                                   random_state=42))],
#                                                  final_estimator=LogisticRegression(max_iter=1000),
#                                                  n_jobs=-1)),
#                              ('lgbm',
#                               LGBMClassifier(colsample_bytree=0.6979333054983232,
#                                              learning_rate=0.29787282209539323,
#                                              max_depth=5, n_estimators=210,
#                                              random_state=42,
#                                              subsample=0.7377503840727486)),
#                              ('catboost',
#                               <catboost.core.CatBoostClassifier object at 0x7c660f54fb90>)],
#                  n_jobs=-1, voting='soft')

# %% [markdown]
# PREDICTION AND EVALUATION

# %%
y_pred = voting_clf.predict(X_test_sel)

print(classification_report(y_test, y_pred))
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       622
#            1       0.98      0.99      0.99       727
#
#     accuracy                           0.99      1349
#    macro avg       0.99      0.99      0.99      1349
# weighted avg       0.99      0.99      0.99      1349
#
# Accuracy: 0.9881

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import RandomForestClassifier, StackingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from imblearn.combine import SMOTEENN
import optuna
import shap


df = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')


df = df[df['gender'] != 'Other']
df.drop('id', axis=1, inplace=True)
df = df[df['work_type'] != 'Never_worked']


df['bmi'] = df['bmi'].fillna(df['bmi'].median())


df['age_glucose'] = df['age'] * df['avg_glucose_level']
df['bmi_age_ratio'] = df['bmi'] / (df['age'] + 1)


df = pd.get_dummies(df, drop_first=True)


X = df.drop('stroke', axis=1)
y = df['stroke']


smote_enn = SMOTEENN(random_state=42)
X_res, y_res = smote_enn.fit_resample(X, y)


X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


lgbm = LGBMClassifier(random_state=42)
lgbm.fit(X_train_scaled, y_train)
explainer = shap.TreeExplainer(lgbm)
shap_values = explainer.shap_values(X_train_scaled)
shap_abs_mean = np.abs(shap_values).mean(axis=0)
important_features_idx = np.argsort(shap_abs_mean)[-15:]

X_train_sel = X_train_scaled[:, important_features_idx]
X_test_sel = X_test_scaled[:, important_features_idx]


def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'random_state': 42,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }
    xgb = XGBClassifier(**param)
    xgb.fit(X_train_sel, y_train)
    preds = xgb.predict(X_test_sel)
    return accuracy_score(y_test, preds)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)
best_params = study.best_params

xgb_opt = XGBClassifier(**best_params)
lgbm_opt = LGBMClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    learning_rate=best_params['learning_rate'],
    subsample=best_params['subsample'],
    colsample_bytree=best_params['colsample_bytree'],
    random_state=42
)
catboost_opt = CatBoostClassifier(verbose=0, random_seed=42)
svc_opt = SVC(probability=True, random_state=42)

estimators = [
    ('xgb', xgb_opt),
    ('lgbm', lgbm_opt),
    ('catboost', catboost_opt),
    ('svc', svc_opt)
]


stacking_clf = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression(max_iter=1000),
    cv=StratifiedKFold(n_splits=5),
    n_jobs=-1,
    passthrough=False
)


voting_clf = VotingClassifier(
    estimators=[
        ('stacking', stacking_clf),
        ('lgbm', lgbm_opt),
        ('catboost', catboost_opt)
    ],
    voting='soft',
    n_jobs=-1
)


voting_clf.fit(X_train_sel, y_train)

y_pred = voting_clf.predict(X_test_sel)
print(classification_report(y_test, y_pred))
print(f"Final Optimized Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 2855, number of negative: 2434
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1308
# [LightGBM] [Info] Number of data points in the train set: 5289, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.539800 -> initscore=0.159536
# [LightGBM] [Info] Start training from score 0.159536
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_tree.py:583: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(
# [I 2025-06-06 14:34:42,996] A new study created in memory with name: no-name-713298b6-d13c-4bf5-a07f-11e0aee6e427
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:43,168] Trial 0 finished with value: 0.9773242630385488 and parameters: {'n_estimators': 94, 'max_depth': 6, 'learning_rate': 0.12093568738686385, 'subsample': 0.9863378916386731, 'colsample_bytree': 0.8335377263877248}. Best is trial 0 with value: 0.9773242630385488.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:43,435] Trial 1 finished with value: 0.9856386999244142 and parameters: {'n_estimators': 188, 'max_depth': 6, 'learning_rate': 0.2611850593135319, 'subsample': 0.7358722158252515, 'colsample_bytree': 0.6424260573288976}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:43,668] Trial 2 finished with value: 0.9758125472411187 and parameters: {'n_estimators': 177, 'max_depth': 5, 'learning_rate': 0.07197580540389713, 'subsample': 0.7447770258938924, 'colsample_bytree': 0.5425473470075772}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:43,820] Trial 3 finished with value: 0.9841269841269841 and parameters: {'n_estimators': 72, 'max_depth': 7, 'learning_rate': 0.2105396990764721, 'subsample': 0.7817480309811151, 'colsample_bytree': 0.9278699041917011}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:44,259] Trial 4 finished with value: 0.9848828420256992 and parameters: {'n_estimators': 289, 'max_depth': 9, 'learning_rate': 0.29969730294030406, 'subsample': 0.8969531385989049, 'colsample_bytree': 0.8078968124302511}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:44,399] Trial 5 finished with value: 0.9788359788359788 and parameters: {'n_estimators': 123, 'max_depth': 4, 'learning_rate': 0.23335775272704873, 'subsample': 0.652293309311867, 'colsample_bytree': 0.6687077833623598}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:44,580] Trial 6 finished with value: 0.9803476946334089 and parameters: {'n_estimators': 146, 'max_depth': 4, 'learning_rate': 0.24299733939596557, 'subsample': 0.6784657618373271, 'colsample_bytree': 0.9441111011774025}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:44,875] Trial 7 finished with value: 0.9803476946334089 and parameters: {'n_estimators': 205, 'max_depth': 6, 'learning_rate': 0.29552120918741526, 'subsample': 0.8043354651744044, 'colsample_bytree': 0.7648856817435619}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:44,997] Trial 8 finished with value: 0.9486016628873771 and parameters: {'n_estimators': 74, 'max_depth': 4, 'learning_rate': 0.03143864521048985, 'subsample': 0.9028248393331568, 'colsample_bytree': 0.87604227224193}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:45,078] Trial 9 finished with value: 0.9682539682539683 and parameters: {'n_estimators': 56, 'max_depth': 4, 'learning_rate': 0.20850956331031179, 'subsample': 0.8948586546059318, 'colsample_bytree': 0.5322114522314367}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:45,517] Trial 10 finished with value: 0.9803476946334089 and parameters: {'n_estimators': 242, 'max_depth': 10, 'learning_rate': 0.14987883424076337, 'subsample': 0.5388266132011093, 'colsample_bytree': 0.6597702357797023}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:45,962] Trial 11 finished with value: 0.982615268329554 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.28709546399048946, 'subsample': 0.8692905163782048, 'colsample_bytree': 0.6612036345724024}. Best is trial 1 with value: 0.9856386999244142.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:46,425] Trial 12 finished with value: 0.9863945578231292 and parameters: {'n_estimators': 291, 'max_depth': 8, 'learning_rate': 0.2673022975497756, 'subsample': 0.9931944580840253, 'colsample_bytree': 0.7565186959722472}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:46,808] Trial 13 finished with value: 0.9773242630385488 and parameters: {'n_estimators': 244, 'max_depth': 8, 'learning_rate': 0.2515046794151203, 'subsample': 0.6088137287344406, 'colsample_bytree': 0.7279603204263263}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:47,230] Trial 14 finished with value: 0.983371126228269 and parameters: {'n_estimators': 240, 'max_depth': 7, 'learning_rate': 0.17226405705746115, 'subsample': 0.9668675605951484, 'colsample_bytree': 0.6034196971973318}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:47,584] Trial 15 finished with value: 0.983371126228269 and parameters: {'n_estimators': 196, 'max_depth': 8, 'learning_rate': 0.1738217427076264, 'subsample': 0.7277535608303558, 'colsample_bytree': 0.7324573094404769}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:47,848] Trial 16 finished with value: 0.9848828420256992 and parameters: {'n_estimators': 139, 'max_depth': 8, 'learning_rate': 0.26120644303489376, 'subsample': 0.8397113398455343, 'colsample_bytree': 0.6065737393809848}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:48,265] Trial 17 finished with value: 0.9841269841269841 and parameters: {'n_estimators': 274, 'max_depth': 6, 'learning_rate': 0.21379395489198783, 'subsample': 0.6916158111521185, 'colsample_bytree': 0.7873243387768615}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:48,491] Trial 18 finished with value: 0.9735449735449735 and parameters: {'n_estimators': 215, 'max_depth': 3, 'learning_rate': 0.11559129978528399, 'subsample': 0.5805957636467143, 'colsample_bytree': 0.9890685779815545}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:48,827] Trial 19 finished with value: 0.9841269841269841 and parameters: {'n_estimators': 170, 'max_depth': 10, 'learning_rate': 0.27978404153203723, 'subsample': 0.8082865004162537, 'colsample_bytree': 0.7033372620334843}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:49,250] Trial 20 finished with value: 0.9856386999244142 and parameters: {'n_estimators': 251, 'max_depth': 7, 'learning_rate': 0.18500910314838254, 'subsample': 0.7170294463456234, 'colsample_bytree': 0.5949411332455168}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:49,674] Trial 21 finished with value: 0.982615268329554 and parameters: {'n_estimators': 267, 'max_depth': 7, 'learning_rate': 0.19127504094639694, 'subsample': 0.7228521823334131, 'colsample_bytree': 0.6001890054501697}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:50,008] Trial 22 finished with value: 0.982615268329554 and parameters: {'n_estimators': 263, 'max_depth': 5, 'learning_rate': 0.26521922467626124, 'subsample': 0.6319165560585488, 'colsample_bytree': 0.505837795504897}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:50,405] Trial 23 finished with value: 0.982615268329554 and parameters: {'n_estimators': 226, 'max_depth': 9, 'learning_rate': 0.22434963737964597, 'subsample': 0.7533067041768202, 'colsample_bytree': 0.6334517216508684}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:50,821] Trial 24 finished with value: 0.9795918367346939 and parameters: {'n_estimators': 181, 'max_depth': 8, 'learning_rate': 0.1373605505794885, 'subsample': 0.5054399112424752, 'colsample_bytree': 0.5602493343981104}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:51,515] Trial 25 finished with value: 0.982615268329554 and parameters: {'n_estimators': 282, 'max_depth': 7, 'learning_rate': 0.18648546991831128, 'subsample': 0.6912229241204962, 'colsample_bytree': 0.6992082480647894}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:51,999] Trial 26 finished with value: 0.9856386999244142 and parameters: {'n_estimators': 255, 'max_depth': 5, 'learning_rate': 0.2686988418931319, 'subsample': 0.943093603492903, 'colsample_bytree': 0.5800201235143737}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:52,593] Trial 27 finished with value: 0.981859410430839 and parameters: {'n_estimators': 222, 'max_depth': 6, 'learning_rate': 0.08199465990313524, 'subsample': 0.7759492070539814, 'colsample_bytree': 0.8568834375626194}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:53,290] Trial 28 finished with value: 0.983371126228269 and parameters: {'n_estimators': 291, 'max_depth': 7, 'learning_rate': 0.2430446450759406, 'subsample': 0.8395495389585848, 'colsample_bytree': 0.6318076309985884}. Best is trial 12 with value: 0.9863945578231292.
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [14:34:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-06-06 14:34:53,547] Trial 29 finished with value: 0.983371126228269 and parameters: {'n_estimators': 115, 'max_depth': 6, 'learning_rate': 0.11887826106558447, 'subsample': 0.9893873062729078, 'colsample_bytree': 0.8185433008402115}. Best is trial 12 with value: 0.9863945578231292.
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       609
#            1       0.98      0.99      0.99       714
#
#     accuracy                           0.99      1323
#    macro avg       0.99      0.99      0.99      1323
# weighted avg       0.99      0.99      0.99      1323
#
# Final Optimized Accuracy: 0.9856
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
